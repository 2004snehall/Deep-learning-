# %% [markdown]
# **Predicting if a person would buy life insurnace based on his age using logistic regression**
#
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Darshana\Downloads\Deep-Learning-assignment\Deep-Learning-main\Insurance Or Not\insurance_data.csv")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Darshana\Downloads\Deep-Learning-assignment\Deep-Learning-main\Insurance Or Not\insurance_data.csv")

# %%
df
# Out:
#     age  affordibility  bought_insurance
# 0    22              1                 0
# 1    25              0                 0
# 2    47              1                 1
# 3    52              0                 0
# 4    46              1                 1
# 5    56              1                 1
# 6    55              0                 0
# 7    60              0                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              1                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              1                 1
# 18   19              0                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# ...

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 17   58
# 0    22
# 18   19
# 10   18
# 21   26
# 14   49

# %%
X_train
# Out:
#     age
# 9    61
# 25   54
# 15   55
# 1    25
# 24   50
# 6    55
# 13   29
# 20   21
# 3    52
# 26   23
# 2    47
# 4    46
# 7    60
# 11   28
# 19   18
# 8    62
# 22   40
# 5    56
# 12   27
# 16   25
# 23   45

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 17   58
# 0    22
# 18   19
# 10   18
# 21   26
# 14   49

# %%
y_test
# Out:
# 17    1
# 0     0
# 18    0
# 10    0
# 21    0
# 14    1
# Name: bought_insurance, dtype: int64

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0, 0, 0, 1])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#     age
# 17   58
# 0    22
# 18   19
# 10   18
# 21   26
# 14   49

# %%
y_predicted = model.predict(X_test)

# %%
y_predicted
# Out:
# array([1, 0, 0, 0, 0, 1])

# %%
y_test
# Out:
# 17    1
# 0     0
# 18    0
# 10    0
# 21    0
# 14    1
# Name: bought_insurance, dtype: int64

# %%
model.predict_proba(X_test)
# Out:
# array([[0.09474616, 0.90525384],
#        [0.86520594, 0.13479406],
#        [0.90045038, 0.09954962],
#        [0.9102408 , 0.0897592 ],
#        [0.80247889, 0.19752111],
#        [0.22653942, 0.77346058]])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([1, 0, 0, 0, 0, 1])

# %%
X_test
# Out:
#     age
# 17   58
# 0    22
# 18   19
# 10   18
# 21   26
# 14   49

# %%
df = pd.read_csv(r"C:\Users\Darshana\Downloads\Deep-Learning-assignment\Deep-Learning-main\HR\HR_comma_sep.csv")

# %%
df1 = pd.read_csv(r"C:\Users\Darshana\Downloads\Deep-Learning-assignment\Deep-Learning-main\HR\HR_comma_sep.csv")
df1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work).
#
# 2. Plot bar charts showing impact of employee salaries on retention.
#
# 3. Plot bar charts showing corelation between department and employee retention.
#
# 4. Now build logistic regression model using variables that were narrowed down in step 1.
#
# 5. Measure the accuracy of the model
